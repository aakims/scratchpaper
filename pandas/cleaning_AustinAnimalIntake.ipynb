# %%
import pandas as pd
import numpy as np

# %%
animalIntakes = pd.read_csv('../data/Austin_Animal_Center_Intakes.csv')

# %%
animalIntakes.head()
#len(animalIntakes) #78709
# Out:
#   Animal ID      Name                DateTime               MonthYear  \
# 0   A748291  *Madison  05/01/2017 02:26:00 PM  05/01/2017 02:26:00 PM
# 1   A750529       NaN  05/28/2017 01:22:00 PM  05/28/2017 01:22:00 PM
# 2   A730601       NaN  07/07/2016 12:11:00 PM  07/07/2016 12:11:00 PM
# 3   A748238       NaN  05/01/2017 10:53:00 AM  05/01/2017 10:53:00 AM
# 4   A683644     *Zoey  07/13/2014 11:02:00 AM  07/13/2014 11:02:00 AM
#
#                                       Found Location      Intake Type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...            Stray
# 1                    8312 North Ih 35 in Austin (TX)            Stray
# 2                       1109 Shady Ln in Austin (TX)            Stray
# 3     Airport Blvd And Oak Springs Dr in Austin (TX)            Stray
# 4                                        Austin (TX)  Owner Surrender
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# ...

# %%
#vagueLocation = animalIntakes[animalIntakes["Found Location"] == "Austin (TX)"]
vagueLocation.head()
#len(vagueLocation) #14109
# Out:
#    Animal ID     Name                DateTime               MonthYear  \
# 4    A683644    *Zoey  07/13/2014 11:02:00 AM  07/13/2014 11:02:00 AM
# 19   A664571      NaN  10/05/2013 01:43:00 PM  10/05/2013 01:43:00 PM
# 23   A724944  Cameron  04/23/2016 11:28:00 AM  04/23/2016 11:28:00 AM
# 27   A671448   Xander  01/24/2014 02:54:00 PM  01/24/2014 02:54:00 PM
# 38   A758853    Buggs  09/23/2017 09:23:00 AM  09/23/2017 09:23:00 AM
#
#    Found Location      Intake Type Intake Condition Animal Type  \
# 4     Austin (TX)  Owner Surrender          Nursing         Dog
# 19    Austin (TX)  Owner Surrender           Normal         Cat
# 23    Austin (TX)  Owner Surrender           Normal         Cat
# 27    Austin (TX)    Public Assist           Normal         Dog
# 38    Austin (TX)  Owner Surrender          Injured         Dog
#
#    Sex upon Intake Age upon Intake                   Breed              Color
# 4    Intact Female         4 weeks       Border Collie Mix        Brown/White
# ...

# %%
wLocData = animalIntakes[animalIntakes["Found Location"] != "Austin (TX)"]
#len(wLocData) #64600
wLocData.head()
# Out:
#   Animal ID      Name                DateTime               MonthYear  \
# 0   A748291  *Madison  05/01/2017 02:26:00 PM  05/01/2017 02:26:00 PM
# 1   A750529       NaN  05/28/2017 01:22:00 PM  05/28/2017 01:22:00 PM
# 2   A730601       NaN  07/07/2016 12:11:00 PM  07/07/2016 12:11:00 PM
# 3   A748238       NaN  05/01/2017 10:53:00 AM  05/01/2017 10:53:00 AM
# 5   A676515      Rico  04/11/2014 08:45:00 AM  04/11/2014 08:45:00 AM
#
#                                       Found Location Intake Type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...       Stray
# 1                    8312 North Ih 35 in Austin (TX)       Stray
# 2                       1109 Shady Ln in Austin (TX)       Stray
# 3     Airport Blvd And Oak Springs Dr in Austin (TX)       Stray
# 5                      615 E. Wonsley in Austin (TX)       Stray
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0           Normal         Dog   Intact Female       10 months
# ...

# %%
wLocData.describe()
# Out:
#        Animal ID   Name                DateTime               MonthYear  \
# count      64600  42000                   64600                   64600
# unique     60592  12757                   45883                   45883
# top      A721033  Bella  07/09/2014 12:58:00 PM  07/09/2014 12:58:00 PM
# freq          11    243                      63                      63
#
#               Found Location Intake Type Intake Condition Animal Type  \
# count                  64600       64600            64600       64600
# unique                 36123           5                8           5
# top     Outside Jurisdiction       Stray           Normal         Dog
# freq                     912       53776            56159       36116
#
#        Sex upon Intake Age upon Intake                   Breed        Color
# count            64599           64600                   64600        64600
# unique               5              46                    1905          500
# ...

# %%
#len(wLocData[wLocData.DateTime.str.contains("2017")]) #14287
#df[df['A'].str.contains("hello")]

mydat = wLocData[wLocData.DateTime.str.contains("2017")]
#mydat.head(100).MonthYear.sort_values() #full year range confirmed 
mydat.head()
# Out:
#    Animal ID      Name                DateTime               MonthYear  \
# 0    A748291  *Madison  05/01/2017 02:26:00 PM  05/01/2017 02:26:00 PM
# 1    A750529       NaN  05/28/2017 01:22:00 PM  05/28/2017 01:22:00 PM
# 3    A748238       NaN  05/01/2017 10:53:00 AM  05/01/2017 10:53:00 AM
# 12   A756485       NaN  08/20/2017 03:07:00 PM  08/20/2017 03:07:00 PM
# 15   A749535    *Bongo  05/16/2017 11:29:00 AM  05/16/2017 11:29:00 AM
#
#                                        Found Location Intake Type  \
# 0   S Pleasant Valley Rd And E Riverside Dr in Aus...       Stray
# 1                     8312 North Ih 35 in Austin (TX)       Stray
# 3      Airport Blvd And Oak Springs Dr in Austin (TX)       Stray
# 12                     1020 Grove Blvd in Austin (TX)       Stray
# 15            6607 S Ih 35 Frontage Rd in Austin (TX)       Stray
#
#    Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0            Normal         Dog   Intact Female       10 months
# ...

# %%
mydat["Found Location"].isnull().sum() #0
# Out:
# 0

# %%
mydat = mydat.rename(columns = {"Found Location":"FoundLocation"})
mydat.head()

##.str.contains("in Austin (TX)").sum()
# Out:
#    Animal ID      Name                DateTime               MonthYear  \
# 0    A748291  *Madison  05/01/2017 02:26:00 PM  05/01/2017 02:26:00 PM
# 1    A750529       NaN  05/28/2017 01:22:00 PM  05/28/2017 01:22:00 PM
# 3    A748238       NaN  05/01/2017 10:53:00 AM  05/01/2017 10:53:00 AM
# 12   A756485       NaN  08/20/2017 03:07:00 PM  08/20/2017 03:07:00 PM
# 15   A749535    *Bongo  05/16/2017 11:29:00 AM  05/16/2017 11:29:00 AM
#
#                                         FoundLocation Intake Type  \
# 0   S Pleasant Valley Rd And E Riverside Dr in Aus...       Stray
# 1                     8312 North Ih 35 in Austin (TX)       Stray
# 3      Airport Blvd And Oak Springs Dr in Austin (TX)       Stray
# 12                     1020 Grove Blvd in Austin (TX)       Stray
# 15            6607 S Ih 35 Frontage Rd in Austin (TX)       Stray
#
#    Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0            Normal         Dog   Intact Female       10 months
# ...

# %%
mydat["FoundLocation"] = mydat["FoundLocation"].str.rstrip("in Austin (TX)")
mydat.head()
# Out:
#    Animal ID      Name                DateTime               MonthYear  \
# 0    A748291  *Madison  05/01/2017 02:26:00 PM  05/01/2017 02:26:00 PM
# 1    A750529       NaN  05/28/2017 01:22:00 PM  05/28/2017 01:22:00 PM
# 3    A748238       NaN  05/01/2017 10:53:00 AM  05/01/2017 10:53:00 AM
# 12   A756485       NaN  08/20/2017 03:07:00 PM  08/20/2017 03:07:00 PM
# 15   A749535    *Bongo  05/16/2017 11:29:00 AM  05/16/2017 11:29:00 AM
#
#                               FoundLocation Intake Type Intake Condition  \
# 0   S Pleasant Valley Rd And E Riverside Dr       Stray           Normal
# 1                          8312 North Ih 35       Stray           Normal
# 3           Airport Blvd And Oak Springs Dr       Stray           Normal
# 12                          1020 Grove Blvd       Stray           Normal
# 15                 6607 S Ih 35 Frontage Rd       Stray           Normal
#
#    Animal Type Sex upon Intake Age upon Intake                    Breed  \
# ...

# %%
mydat['city'] = "Austin"
mydat['state'] = "TX"

# %%
mydat[mydat['MonthYear'] != mydat['DateTime']].head()
# Out:
# Empty DataFrame
# Columns: [Animal ID, Name, DateTime, MonthYear, FoundLocation, Intake Type, Intake Condition, Animal Type, Sex upon Intake, Age upon Intake, Breed, Color, city, state]
# Index: []

# %%
mydat.columns = ['animal_id','name','date_time','month_year','found_loc','intake_type','intake_condition','animal_type','sex','age','breed','color','city','state']

# %%
#mydat = mydat.reset_index()
mydat.head()
mydat = mydat.rename(columns = {"level_0":"index1"})
mydat.head()
# Out:
#    index1  index animal_id      name               date_time  \
# 0       0      0   A748291  *Madison  05/01/2017 02:26:00 PM
# 1       1      1   A750529       NaN  05/28/2017 01:22:00 PM
# 2       2      3   A748238       NaN  05/01/2017 10:53:00 AM
# 3       3     12   A756485       NaN  08/20/2017 03:07:00 PM
# 4       4     15   A749535    *Bongo  05/16/2017 11:29:00 AM
#
#                month_year                                found_loc  \
# 0  05/01/2017 02:26:00 PM  S Pleasant Valley Rd And E Riverside Dr
# 1  05/28/2017 01:22:00 PM                         8312 North Ih 35
# 2  05/01/2017 10:53:00 AM          Airport Blvd And Oak Springs Dr
# 3  08/20/2017 03:07:00 PM                          1020 Grove Blvd
# 4  05/16/2017 11:29:00 AM                 6607 S Ih 35 Frontage Rd
#
#   intake_type intake_condition animal_type            sex        age  \
# 0       Stray           Normal         Dog  Intact Female  10 months
# ...

# %%
mydat.to_csv("../data/Austin_AnimalIntake_addresscleaned.csv")
